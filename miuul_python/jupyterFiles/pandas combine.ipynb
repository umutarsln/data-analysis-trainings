# %%
import pandas as pd
import numpy as np

# %%
n_array = np.random.randint(1,30, size=(5,3))

# %%
df1 = pd.DataFrame(n_array, columns=["va1","var2","var3"])

# %%
df1
# Out:
#    va1  var2  var3
# 0   20    17    23
# 1   26     4     6
# 2    5     2    26
# 3   24     7     5
# 4    7    12    13

# %%
df2 = df1 *2

# %%
df2
# Out:
#    va1  var2  var3
# 0   40    34    46
# 1   52     8    12
# 2   10     4    52
# 3   48    14    10
# 4   14    24    26

# %%
pd.concat([df1,df2], ignore_index=True)
# Out:
#    va1  var2  var3
# 0   20    17    23
# 1   26     4     6
# 2    5     2    26
# 3   24     7     5
# 4    7    12    13
# 5   40    34    46
# 6   52     8    12
# 7   10     4    52
# 8   48    14    10
# 9   14    24    26

# %%
df3 = pd.DataFrame({"employees": ["john","dennis","mark","maria"],
                  "group": ["accounting","engineering","engineering","hr"]})
df4 = pd.DataFrame({"employees": ["mark","john","dennis","maria"],
                    "start_date": [2010,2009,2004,2019]})

# %%
df4
# Out:
#   employees  start_date
# 0      mark        2010
# 1      john        2009
# 2    dennis        2004
# 3     maria        2019

# %%
# Default merge "employess"
pd.merge(df3,df4)
# Out:
#   employees        group  start_date
# 0      john   accounting        2009
# 1    dennis  engineering        2004
# 2      mark  engineering        2010
# 3     maria           hr        2019

# %%
pd.merge(df3,df4, on="employees")
# Out:
#   employees        group  start_date
# 0      john   accounting        2009
# 1    dennis  engineering        2004
# 2      mark  engineering        2010
# 3     maria           hr        2019
