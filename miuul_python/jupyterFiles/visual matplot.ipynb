# %%
import pandas as pd
import seaborn as sns
import numpy as np

df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
import matplotlib.pyplot as plt

# %%
df["sex"].value_counts().plot(kind="bar")
plt.show()

# %%
plt.hist(df["age"])
#plt.show()
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(df["fare"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fbf82d5e9d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7fbf98d22130>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7fbf82d5e670>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fbf98d227f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fbf98d22a90>],
#  'means': []}

# %%
x = np.array([1,8])
y = np.array([0,150])

plt.plot(x,y,'o')
plt.show()

# %%
x = np.array([1,3,5,7,9])
y = np.array([3,6,9,12,15])

plt.plot(x,y,"o")

# %%
x = np.array([1,20,7,3,14])

plt.plot(x,marker="*")

# %%
x = np.array([1,20,7,3,14])

# "dashed" , "dotted" , "dashdot"
plt.plot(x,linestyle="dotted",color="red")

# %%
x = np.array([1,20,7,3,14])
y = np.array([3,8,1,14,8])

plt.plot(x)
plt.plot(y)
plt.show()

# %%
x = np.array([1,20,7,3,14])
y = np.array([3,8,1,14,8])

plt.plot(x,y)
plt.title("Tablo Başlık")
plt.xlabel("size")
plt.ylabel("weight")
plt.show()

# %%
x = np.array([5,10,15,20,25])
y = np.array([12,4,6,2,9])

plt.subplot(1,2,1)
plt.title("1. Grafik")
plt.plot(x,y)

plt.subplot(1,2,2)
plt.title("2. Grafik")
plt.plot(y,x)
plt.show()
