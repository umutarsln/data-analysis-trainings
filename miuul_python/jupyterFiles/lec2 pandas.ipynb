# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
"age" in df
# Out:
# True

# %%
df["age"].head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: age, dtype: float64

# %%
# Tek köşeli parantezle seçim bize pandas serisi verir !!!
type(df["age"].head())
# Out:
# pandas.core.series.Series

# %%
df[["age"]].head()
# Out:
#     age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
# Çift köşeli parantezle seçim bize dataframe verir !!!
type(df[["age"]].head())
# Out:
# pandas.core.frame.DataFrame

# %%
df[["age","alive"]]
# Out:
#       age alive
# 0    22.0    no
# 1    38.0   yes
# 2    26.0   yes
# 3    35.0   yes
# 4    35.0    no
# ..    ...   ...
# 886  27.0    no
# 887  19.0   yes
# 888   NaN    no
# 889  26.0   yes
# 890  32.0    no
#
# [891 rows x 2 columns]

# %%
col_names = ["age","alive","class"]
df.drop(col_names, axis=1).head()
# Out:
#    survived  pclass     sex  sibsp  parch     fare embarked    who  \
# 0         0       3    male      1      0   7.2500        S    man
# 1         1       1  female      1      0  71.2833        C  woman
# 2         1       3  female      0      0   7.9250        S  woman
# 3         1       1  female      1      0  53.1000        S  woman
# 4         0       3    male      0      0   8.0500        S    man
#
#    adult_male deck  embark_town  alone
# 0        True  NaN  Southampton  False
# 1       False    C    Cherbourg  False
# 2       False  NaN  Southampton   True
# 3       False    C  Southampton  False
# 4        True  NaN  Southampton   True

# %%
df["age2"] = df["age"]*3
df["age3"] = df["age"]/2

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df.loc[:, df.columns.str.contains("age")]
# Out:
#       age   age2  age3
# 0    22.0   66.0  11.0
# 1    38.0  114.0  19.0
# 2    26.0   78.0  13.0
# 3    35.0  105.0  17.5
# 4    35.0  105.0  17.5
# ..    ...    ...   ...
# 886  27.0   81.0  13.5
# 887  19.0   57.0   9.5
# 888   NaN    NaN   NaN
# 889  26.0   78.0  13.0
# 890  32.0   96.0  16.0
#
# [891 rows x 3 columns]
